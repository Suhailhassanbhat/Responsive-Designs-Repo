# %% [markdown]
# # Long Island multi-family housing units
# By Suhail
#
# talk about the process and the data and who this is for

# %%
import pandas as pd
import re

import matplotlib as plt
import seaborn as sns

# %%
housing = pd.read_csv('housing.csv')
housing['fixedYear'] = housing.year.str.extract(r"(\d\d\d\d)").astype(float)

# %%
df = housing[housing.fixedYear > 1969]

# %% [markdown]
# descriptor of the data below. more housing projects now

# %%
df.head(1)
# Out:
#                                             the_geom   county  \
# 0  0101000020E6100000B7F4C3639A2F52C0A99D06B1D87B...  Suffolk
#
#   city_village_or_cdp housing_type              complex_name  \
# 0      Baiting Hollow         COND  Vistas of Baiting Hollow
#
#     complex_address  units  acres status  year  ...  longitude accuracy_score  \
# 0  100 Fox Hill Dr.     21    8.0   PROP  2016  ... -72.743798            1.0
#
#     accuracy_type number       street       city  zip country         source  \
# 0  street_address    100  Fox Hill Dr  Riverhead  NaN      US  Google Script
#
#   fixedYear
# 0    2016.0
#
# [1 rows x 25 columns]

# %%
df.fixedYear.hist()

# %%
overTime = df.groupby('housing_type').fixedYear.value_counts().reset_index(name='count')

sns.lineplot(data=overTime, x='fixedYear',y='count', hue='housing_type')

# %%
df.to_csv('housing-cleaned.csv', index=False)

# %%
sns.lineplot(data=df, x='fixedYear',y='units')
